# %%
import csv
sum = 0
with open("aoc3.csv", 'r') as file:
  for row in csv.reader(file):
    nr1, nr2 = int(row[0].split("-")[0]), int(row[0].split("-")[1])
    nr3, nr4 = int(row[1].split("-")[0]), int(row[1].split("-")[1])
    if nr1 >= nr3 and nr1 <= nr4 and nr2 >= nr3 and nr2 <=nr4:
        sum +=1
    elif nr3 >= nr1 and nr3 <= nr2 and nr4 >= nr1 and nr4 <=nr2:
        sum +=1
    else:
        print(row)

print(sum)
# Out:
# ['4-90', '1-4']
# ['1-97', '96-99']
# ['7-25', '24-48']
# ['4-98', '1-1']
# ['9-14', '15-84']
# ['87-98', '22-81']
# ['30-95', '29-29']
# ['1-1', '3-87']
# ['86-90', '91-98']
# ['59-67', '60-79']
# ['10-78', '1-6']
# ['91-95', '7-81']
# ['15-60', '14-14']
# ['46-70', '45-69']
# ['74-74', '25-73']
# ['1-95', '95-98']
# ['8-70', '70-71']
# ['35-43', '38-60']
# ['87-97', '52-96']
# ['1-3', '7-90']
# ['91-93', '10-92']
# ['34-50', '51-51']
# ['26-72', '42-73']
# ['78-85', '22-79']
# ['52-93', '51-52']
# ['28-78', '6-77']
# ['35-95', '13-43']
# ['99-99', '73-92']
# ['4-74', '92-96']
# ['11-53', '54-86']
# ['21-78', '16-21']
# ['49-72', '71-78']
# ['77-94', '35-63']
# ['7-96', '6-94']
# ['19-88', '12-87']
# ['13-64', '4-63']
# ['69-79', '79-86']
# ['66-80', '2-79']
# ['11-82', '3-6']
# ['7-16', '16-36']
# ['3-64', '98-98']
# ['19-94', '95-95']
# ['86-91', '29-86']
# ['27-85', '86-86']
# ['1-3', '3-82']
# ['25-25', '40-46']
# ['52-77', '51-76']
# ['21-83', '22-91']
# ['17-62', '18-63']
# ...

# %%
import csv
sum = 0
with open("aoc3.csv", 'r') as file:
  for row in csv.reader(file):
    nr1, nr2 = int(row[0].split("-")[0]), int(row[0].split("-")[1])
    nr3, nr4 = int(row[1].split("-")[0]), int(row[1].split("-")[1])

    if nr1 >= nr3 and nr1 <=nr4:
      sum +=1
    elif nr2 >= nr3 and nr2 <=nr4:
      sum +=1
    elif nr3 >= nr1 and nr3 <=nr2:
        sum +=1
    elif nr4 >= nr1 and nr4 <=nr2:
      sum +=1

    else:
        print(row)

print(sum)
# Out:
# ['4-98', '1-1']
# ['9-14', '15-84']
# ['87-98', '22-81']
# ['30-95', '29-29']
# ['1-1', '3-87']
# ['86-90', '91-98']
# ['10-78', '1-6']
# ['91-95', '7-81']
# ['15-60', '14-14']
# ['74-74', '25-73']
# ['1-3', '7-90']
# ['34-50', '51-51']
# ['99-99', '73-92']
# ['4-74', '92-96']
# ['11-53', '54-86']
# ['77-94', '35-63']
# ['11-82', '3-6']
# ['3-64', '98-98']
# ['19-94', '95-95']
# ['27-85', '86-86']
# ['25-25', '40-46']
# ['22-22', '14-21']
# ['1-97', '98-99']
# ['44-44', '45-54']
# ['95-95', '5-79']
# ['20-25', '28-67']
# ['22-25', '29-51']
# ['49-76', '29-32']
# ['17-52', '77-92']
# ['4-53', '2-2']
# ['6-69', '70-70']
# ['60-98', '59-59']
# ['72-72', '71-71']
# ['39-96', '38-38']
# ['2-97', '98-99']
# ['77-96', '11-62']
# ['12-14', '22-43']
# ['12-90', '11-11']
# ['8-77', '7-7']
# ['11-87', '2-2']
# ['45-45', '46-46']
# ['36-36', '37-74']
# ['98-99', '31-97']
# ['5-5', '10-71']
# ['3-3', '4-99']
# ['11-71', '4-8']
# ['51-83', '85-85']
# ['63-97', '98-99']
# ['76-97', '98-99']
# ...
